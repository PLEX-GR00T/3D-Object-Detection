# %% [markdown]
# <a href="https://colab.research.google.com/github/PLEX-GR00T/3D-Object-Detection/blob/main/Roboflow_Train_YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Train YOLOv5 on Custom Objects
#
# This tutorial is based on the [YOLOv5 repository](https://github.com/ultralytics/yolov5) by [Ultralytics](https://www.ultralytics.com/). This notebook shows training on **your own custom objects**. Many thanks to Ultralytics for putting this repository together - we hope that in combination with clean data management tools at Roboflow, this technologoy will become easily accessible to any developer wishing to use computer vision in their projects.
#
# ### Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on [how to train YOLOv5](https://blog.roboflow.ai/how-to-train-yolov5-on-a-custom-dataset/), concurrently.
#
# ### Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train YOLOv5 on your custom objects. We use a [public blood cell detection dataset](https://public.roboflow.ai/object-detection/bccd), which is open source and free to use. You can also use this notebook on your own data.
#
# To train our detector we take the following steps:
#
# * Install YOLOv5 dependencies
# * Download custom YOLOv5 object detection data
# * Write our YOLOv5 Training configuration
# * Run YOLOv5 training
# * Evaluate YOLOv5 performance
# * Visualize YOLOv5 training data
# * Run YOLOv5 inference on test images
# * Export saved YOLOv5 weights for future inference
#
#
#
# ### **About**
#
# [Roboflow](https://roboflow.com) enables teams to deploy custom computer vision models quickly and accurately. Convert data from to annotation format, assess dataset health, preprocess, augment, and more. It's free for your first 1000 source images.
#
# **Looking for a vision model available via API without hassle? Try Roboflow Train.**
#
# ![Roboflow Wordmark](https://i.imgur.com/dcLNMhV.png)

# %% [markdown]
# #Install Dependencies
#
# _(Remember to choose GPU in Runtime if not already selected. Runtime --> Change Runtime Type --> Hardware accelerator --> GPU)_

# %%
# clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# !git reset --hard 886f1c03d839575afecb059accf74296fad395b6
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10152, done.
# remote: Total 10152 (delta 0), reused 0 (delta 0), pack-reused 10152
# Receiving objects: 100% (10152/10152), 10.44 MiB | 19.16 MiB/s, done.
# Resolving deltas: 100% (7032/7032), done.
# /content/yolov5
# HEAD is now at 886f1c0 DDP after autoanchor reorder (#2421)

# %%
# install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch

from IPython.display import Image, clear_output  # to display images
from utils.google_utils import gdrive_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
#      |████████████████████████████████| 596 kB 5.2 MB/s
# Setup complete. Using torch 1.10.0+cu111 _CudaDeviceProperties(name='Tesla K80', major=3, minor=7, total_memory=11441MB, multi_processor_count=13)

# %% [markdown]
# # Download Correctly Formatted Custom Dataset
#
# We'll download our dataset from Roboflow. Use the "**YOLOv5 PyTorch**" export format. Note that the Ultralytics implementation calls for a YAML file defining where your training and test data is. The Roboflow export also writes this format for us.
#
# To get your data into Roboflow, follow the [Getting Started Guide](https://blog.roboflow.ai/getting-started-with-roboflow/).

# %% [markdown]
# ![YOLOv5 PyTorch export](https://i.imgur.com/5vr9G2u.png)

# %%
#follow the link below to get your download code from from Roboflow
# !pip install -q roboflow
from roboflow import Roboflow
rf = Roboflow(model_format="yolov5", notebook="roboflow-yolov5")
# Out:
#      |████████████████████████████████| 145 kB 5.4 MB/s
#      |████████████████████████████████| 178 kB 41.0 MB/s
#      |████████████████████████████████| 1.1 MB 36.9 MB/s
#      |████████████████████████████████| 67 kB 4.9 MB/s
#      |████████████████████████████████| 138 kB 33.2 MB/s
#      |████████████████████████████████| 62 kB 778 kB/s
#   Building wheel for roboflow (setup.py) ... done
#   Building wheel for wget (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=yolov5&ref=roboflow-yolov5

# %%
# %cd /content/yolov5
#after following the link above, recieve python code with these fields filled in
#from roboflow import Roboflow
#rf = Roboflow(api_key="YOUR API KEY HERE")
#project = rf.workspace().project("YOUR PROJECT")
#dataset = project.version("YOUR VERSION").download("yolov5")

from roboflow import Roboflow
rf = Roboflow(api_key="KVKyP3ShZBDuGOU4Qjbf")
project = rf.workspace().project("roadside-object-detection")
dataset = project.version(7).download("yolov5")
# Out:
# /content/yolov5
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Roadside-Object-Detection-7 to yolov5pytorch: 100% [163141323 / 163141323] bytes
# Extracting Dataset Version Zip to Roadside-Object-Detection-7 in yolov5pytorch:: 100%|██████████| 3742/3742 [00:06<00:00, 555.61it/s]

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat {dataset.location}/data.yaml
# Out:
# names:
# - Car
# - Heavy Vehicle
# - Worker
# - pedestrian
# nc: 4
# train: Roadside-Object-Detection-7/train/images
# val: Roadside-Object-Detection-7/valid/images

# %% [markdown]
# # Define Model Configuration and Architecture
#
# We will write a yaml script that defines the parameters for our model like the number of classes, anchors, and each layer.
#
# You do not need to edit these cells, but you may.

# %%
# define number of classes based on YAML
import yaml
with open(dataset.location + "/data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
#this is the model configuration we will use for our tutorial 
# %cat /content/yolov5/models/yolov5s.yaml
# Out:
# # parameters
# nc: 80  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, C3, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate /content/yolov5/models/custom_yolov5s.yaml
#
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **nosave:** only save the final checkpoint
# - **cache:** cache images for faster training

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --img 416 --batch 16 --epochs 100 --data {dataset.location}/data.yaml --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# Out:
# /content/yolov5
# github: ⚠️ WARNING: code is out of date by 714 commits. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# YOLOv5 v4.0-126-g886f1c0 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=True, cfg='./models/custom_yolov5s.yaml', data='/content/yolov5/Roadside-Object-Detection-7/data.yaml', device='', entity=None, epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[416, 416], linear_lr=False, local_rank=-1, log_artifacts=False, log_imgs=16, multi_scale=False, name='yolov5s_results', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov5s_results', single_cls=False, sync_bn=False, total_batch_size=16, weights='', workers=8, world_size=1)
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1     24273  models.yolo.Detect                      [4, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 283 layers, 7263185 parameters, 7263185 gradients, 16.8 GFLOPS
#
# Scaled weight_decay = 0.0005
# Optimizer groups: 62 .bias, 70 conv.weight, 59 other
# train: Scanning 'Roadside-Object-Detection-7/train/labels' for images and labels... 1514 found, 0 missing, 162 empty, 0 corrupted: 100% 1514/1514 [00:00<00:00, 2305.22it/s]
# train: New cache created: Roadside-Object-Detection-7/train/labels.cache
# train: Caching images (0.8GB): 100% 1514/1514 [00:17<00:00, 88.65it/s]
# val: Scanning 'Roadside-Object-Detection-7/valid/labels' for images and labels... 234 found, 0 missing, 20 empty, 0 corrupted: 100% 234/234 [00:00<00:00, 1072.35it/s]
# val: New cache created: Roadside-Object-Detection-7/valid/labels.cache
# val: Caching images (0.1GB): 100% 234/234 [00:03<00:00, 58.59it/s]
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 4.99, Best Possible Recall (BPR) = 0.9982
# Image sizes 416 train, 416 test
# Using 2 dataloader workers
# Logging results to runs/train/yolov5s_results
# Starting training for 100 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 8/8 [00:03<00:00,  2.55it/s]
#                  all         234         658       0.593       0.418       0.459       0.182
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      98/99     1.81G   0.04284   0.02847  0.007418   0.07872        47       416: 100% 95/95 [00:39<00:00,  2.38it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 8/8 [00:03<00:00,  2.53it/s]
#                  all         234         658       0.589       0.437       0.474        0.19
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      99/99     1.81G     0.043   0.02903  0.007114   0.07914        51       416: 100% 95/95 [00:39<00:00,  2.38it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 8/8 [00:04<00:00,  1.82it/s]
#                  all         234         658       0.587       0.458       0.461       0.179
#                  Car         234         287       0.688       0.746       0.737       0.331
#        Heavy Vehicle         234          90       0.746       0.588        0.65       0.273
#               Worker         234         113       0.399       0.247       0.218      0.0625
#           pedestrian         234         168       0.514        0.25       0.239      0.0507
# Optimizer stripped from runs/train/yolov5s_results/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/yolov5s_results/weights/best.pt, 14.8MB
# 100 epochs completed in 1.232 hours.
#
# CPU times: user 54.1 s, sys: 8.47 s, total: 1min 2s
# Wall time: 1h 14min 41s

# %% [markdown]
# # Evaluate Custom YOLOv5 Detector Performance

# %% [markdown]
# Training losses and performance metrics are saved to Tensorboard and also to a logfile defined above with the **--name** flag when we train. In our case, we named this `yolov5s_results`. (If given no name, it defaults to `results.txt`.) The results file is plotted as a png after training completes.
#
# Note from Glenn: Partially completed `results.txt` files can be plotted with `from utils.utils import plot_results; plot_results()`.

# %%
# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# we can also output some older school graphs if the tensor board isn't working for whatever reason... 
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results/results.png', width=1000)  # view results.png

# %% [markdown]
# ### Curious? Visualize Our Training Data with Labels
#
# After training starts, view `train*.jpg` images to see training images, labels and augmentation effects.
#
# Note a mosaic dataloader is used for training (shown below), a new dataloading concept developed by Glenn Jocher and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
# first, display our ground truth data
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/test_batch0_labels.jpg', width=900)
# Out:
# GROUND TRUTH TRAINING DATA:

# %%
# print out an augmented training example
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/train_batch0.jpg', width=900)
# Out:
# GROUND TRUTH AUGMENTED TRAINING DATA:

# %% [markdown]
# #Run Inference  With Trained Weights
# Run inference with a pretrained checkpoint on contents of `test/images` folder downloaded from Roboflow.

# %%
# trained weights are saved by default in our weights folder
# %ls runs/
# Out:
# train/

# %%
# %ls runs/train/yolov5s_results/weights
# Out:
# best.pt  last.pt

# %%
# when we ran this, we saw .007 second inference time. That is 140 FPS on a TESLA P100!
# use the best weights!
# %cd /content/yolov5/
# !python detect.py --weights runs/train/yolov5s_results/weights/best.pt --img 416 --conf 0.4 --source /content/yolov5/Roadside-Object-Detection-7/test/images
# Out:
# /content/yolov5
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=416, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='/content/yolov5/Roadside-Object-Detection-7/test/images', update=False, view_img=False, weights=['runs/train/yolov5s_results/weights/best.pt'])
# YOLOv5 v4.0-126-g886f1c0 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 232 layers, 7254609 parameters, 0 gradients, 16.8 GFLOPS
# image 1/117 /content/yolov5/Roadside-Object-Detection-7/test/images/000012_jpg.rf.0ea4739f8d2a9ace1784a584ce37a80b.jpg: 416x416 Done. (0.031s)
# image 2/117 /content/yolov5/Roadside-Object-Detection-7/test/images/000015_jpg.rf.365cbf684508fd3ef1488c114f289e77.jpg: 416x416 Done. (0.031s)
# image 3/117 /content/yolov5/Roadside-Object-Detection-7/test/images/000021_jpg.rf.d84839e24a7b9e60c6db63df5263a804.jpg: 416x416 Done. (0.031s)
# image 4/117 /content/yolov5/Roadside-Object-Detection-7/test/images/000025_jpg.rf.e2de0fdd9b9531595d2219f37ec47254.jpg: 416x416 Done. (0.031s)
# image 5/117 /content/yolov5/Roadside-Object-Detection-7/test/images/000026_jpg.rf.fb1d1681437e7f5c9951dd2b3bc4d9cc.jpg: 416x416 1 Worker, Done. (0.033s)
# image 6/117 /content/yolov5/Roadside-Object-Detection-7/test/images/00003_jpg.rf.2c4c579bb86921a4e67ffecb7c48fe2b.jpg: 416x416 1 Heavy Vehicle, Done. (0.032s)
# image 7/117 /content/yolov5/Roadside-Object-Detection-7/test/images/000046_jpg.rf.e1db404a79ccf8c0eae33b2f7c5ca1e4.jpg: 416x416 Done. (0.031s)
# image 8/117 /content/yolov5/Roadside-Object-Detection-7/test/images/000068_jpg.rf.a1ca1d0ffb6d62f71ec8f7bd7bd9f7f8.jpg: 416x416 Done. (0.031s)
# image 9/117 /content/yolov5/Roadside-Object-Detection-7/test/images/00008_jpg.rf.9a5dc03ab377e1e36009e6c48dd96ee3.jpg: 416x416 Done. (0.032s)
# image 10/117 /content/yolov5/Roadside-Object-Detection-7/test/images/00020_jpg.rf.1f6e93625054869e6af907329f7b0233.jpg: 416x416 Done. (0.031s)
# image 11/117 /content/yolov5/Roadside-Object-Detection-7/test/images/00028_jpg.rf.464d51a22e12788b59daf913fc5ab5ca.jpg: 416x416 1 Car, Done. (0.033s)
# image 12/117 /content/yolov5/Roadside-Object-Detection-7/test/images/00039_jpg.rf.7bef8d66997141ef92c189cdc152bdd9.jpg: 416x416 2 Cars, Done. (0.032s)
# image 13/117 /content/yolov5/Roadside-Object-Detection-7/test/images/00041_jpg.rf.dc85536690723a63e9ed386223c81391.jpg: 416x416 2 Cars, Done. (0.032s)
# image 14/117 /content/yolov5/Roadside-Object-Detection-7/test/images/14_jpg.rf.3aa98a60f2bc3a1baf5d9b4e3331f8e5.jpg: 416x416 Done. (0.031s)
# image 15/117 /content/yolov5/Roadside-Object-Detection-7/test/images/21_jpg.rf.6e6e7600405fe31d20b1a3fe428c4524.jpg: 416x416 Done. (0.031s)
# image 16/117 /content/yolov5/Roadside-Object-Detection-7/test/images/22_jpg.rf.8808d29ac50771ca58b62b034735e9d0.jpg: 416x416 Done. (0.031s)
# image 17/117 /content/yolov5/Roadside-Object-Detection-7/test/images/25_jpg.rf.4ccc7f961971b7ef42fe26ead3ccc848.jpg: 416x416 Done. (0.031s)
# image 18/117 /content/yolov5/Roadside-Object-Detection-7/test/images/30_000_-Pedestrian-Pictures-_-Download-----1-_jpeg.rf.7122403c975f131412045dd5a329741e.jpg: 416x416 Done. (0.031s)
# image 19/117 /content/yolov5/Roadside-Object-Detection-7/test/images/America-desperately-needs-1-million---_jpeg.rf.35d586b839df7feab3278cbfa396024b.jpg: 416x416 2 Workers, Done. (0.032s)
# image 20/117 /content/yolov5/Roadside-Object-Detection-7/test/images/COVID-19---Control-and-Prevention---_jpeg.rf.ed7f262ad2aeeb92c120a97d56d2dda8.jpg: 416x416 Done. (0.031s)
# image 21/117 /content/yolov5/Roadside-Object-Detection-7/test/images/Construction-Worker-Rights-_-Gordon---_jpeg.rf.9b6e438aa945fab1e5ab3cc41c649610.jpg: 416x416 2 Workers, Done. (0.032s)
# image 22/117 /content/yolov5/Roadside-Object-Detection-7/test/images/Construction-Workers-on-Going-to-Work-----1-_jpeg.rf.2c028e9b255b355e4bc59cb05be8cc54.jpg: 416x416 1 Worker, Done. (0.032s)
# image 23/117 /content/yolov5/Roadside-Object-Detection-7/test/images/Construction_-agricultural-workers-at---_jpeg.rf.10ff27042527b5b12009d7b0f2e71eaa.jpg: 416x416 Done. (0.031s)
# image 24/117 /content/yolov5/Roadside-Object-Detection-7/test/images/Eased-coronavirus-restrictions-in-Spain---_jpeg.rf.b2dc0c9df7edfe0fbda1bf402f32bcc1.jpg: 416x416 1 Worker, Done. (0.030s)
# image 25/117 /content/yolov5/Roadside-Object-Detection-7/test/images/Here_s-what-it_s-like-to-be-a-woman---_jpeg.rf.a3396318b6147433952c783b4bf2bf9b.jpg: 416x416 1 Worker, Done. (0.032s)
# image 26/117 /content/yolov5/Roadside-Object-Detection-7/test/images/Los-Angeles-Construction-Accident---_jpeg.rf.ba0c9c1f6fa49203ca66200c15e5fec9.jpg: 416x416 Done. (0.031s)
# image 27/117 /content/yolov5/Roadside-Object-Detection-7/test/images/October-is-National-Pedestrian-Safety---_jpeg.rf.b4bf4bf880ddd8408c949887fe683291.jpg: 416x416 2 Cars, Done. (0.032s)
# image 28/117 /content/yolov5/Roadside-Object-Detection-7/test/images/Pedestrian-Collision-Warning-_-Mobileye---_jpeg.rf.3ac02d201b4ef7ad5b4c8214c29455d6.jpg: 416x416 2 pedestrians, Done. (0.032s)
# image 29/117 /content/yolov5/Roadside-Object-Detection-7/test/images/Pedestrian-Safety-on-U-S--Streets----_jpeg.rf.acdf2034953573803cb7360bc2c41b20.jpg: 416x416 4 Cars, Done. (0.032s)
# image 30/117 /content/yolov5/Roadside-Object-Detection-7/test/images/Pedestrians-and-Cyclists_-Better---_jpeg.rf.b89ddd75698cbf6106c2d531276c0071.jpg: 416x416 1 Car, Done. (0.032s)
# image 31/117 /content/yolov5/Roadside-Object-Detection-7/test/images/The-US-needs-construction-workers---KESQ_jpeg.rf.7245f5e2e2aaf97d4031b12c6a35d683.jpg: 416x416 Done. (0.031s)
# image 32/117 /content/yolov5/Roadside-Object-Detection-7/test/images/Train_-Construction-Worker---Career---_jpeg.rf.7489035bd59438367300f51935df4265.jpg: 416x416 Done. (0.031s)
# image 33/117 /content/yolov5/Roadside-Object-Detection-7/test/images/Without-more-construction-workers---_jpeg.rf.f1c906bb9ef95a069d53eec536a1c452.jpg: 416x416 1 Worker, Done. (0.032s)
# image 34/117 /content/yolov5/Roadside-Object-Detection-7/test/images/b12_jpg.rf.fe54e853ae0f4482b1f09e1d3607674f.jpg: 416x416 Done. (0.031s)
# image 35/117 /content/yolov5/Roadside-Object-Detection-7/test/images/b16_jpg.rf.7dbabd81dc767fffd49ceff52bf75051.jpg: 416x416 Done. (0.031s)
# image 36/117 /content/yolov5/Roadside-Object-Detection-7/test/images/bike_-14-_jpg.rf.0b97ada47dd78f3c01ba4a95f6fae0ea.jpg: 416x416 Done. (0.031s)
# image 37/117 /content/yolov5/Roadside-Object-Detection-7/test/images/bike_-16-_jpg.rf.26a02d3e0a634d448d8490a8b0458670.jpg: 416x416 Done. (0.031s)
# image 38/117 /content/yolov5/Roadside-Object-Detection-7/test/images/bike_-18-_jpg.rf.4c3d0e91f6fc3aadc668566d8f192450.jpg: 416x416 Done. (0.031s)
# image 39/117 /content/yolov5/Roadside-Object-Detection-7/test/images/bike_-25-_jpg.rf.4393a3a88b34b8e119e3f63e5df82430.jpg: 416x416 Done. (0.031s)
# image 40/117 /content/yolov5/Roadside-Object-Detection-7/test/images/bike_-27-_jpg.rf.7da0243844e3d0ff05493bd53995d65d.jpg: 416x416 Done. (0.031s)
# image 41/117 /content/yolov5/Roadside-Object-Detection-7/test/images/bike_-42-_jpg.rf.9b43363c7fc0b7bb83c070b932ae9bd6.jpg: 416x416 Done. (0.031s)
# image 42/117 /content/yolov5/Roadside-Object-Detection-7/test/images/bike_-43-_jpg.rf.8d62228cb35a52ac1f36983087c10d92.jpg: 416x416 Done. (0.031s)
# image 43/117 /content/yolov5/Roadside-Object-Detection-7/test/images/bike_-67-_jpg.rf.52b2233d32e2627fe5d9bdaabfe9cb6a.jpg: 416x416 1 Car, Done. (0.032s)
# image 44/117 /content/yolov5/Roadside-Object-Detection-7/test/images/bike_-70-_jpg.rf.7aa17cf81cdd0419a046b1102f21a243.jpg: 416x416 1 Car, Done. (0.032s)
# image 45/117 /content/yolov5/Roadside-Object-Detection-7/test/images/bike_-75-_jpg.rf.6a122379defafae9bb27715cf7f7130e.jpg: 416x416 1 Car, Done. (0.033s)
# image 46/117 /content/yolov5/Roadside-Object-Detection-7/test/images/hv_-1-_jpg.rf.c28777447f096d834293dabc2d8228bf.jpg: 416x416 1 Car, Done. (0.032s)
# image 47/117 /content/yolov5/Roadside-Object-Detection-7/test/images/hv_-103-_jpg.rf.d28eeafc5fdb7edb662f5a1f2421be26.jpg: 416x416 1 Car, 1 Heavy Vehicle, Done. (0.032s)
# image 48/117 /content/yolov5/Roadside-Object-Detection-7/test/images/hv_-117-_jpg.rf.81d82d42908f1b8f2e052b48bdbb8777.jpg: 416x416 1 Car, Done. (0.032s)
# image 49/117 /content/yolov5/Roadside-Object-Detection-7/test/images/hv_-138-_jpg.rf.c41c7df754b5c021c1d7622db89439ec.jpg: 416x416 1 Heavy Vehicle, Done. (0.032s)
# image 50/117 /content/yolov5/Roadside-Object-Detection-7/test/images/hv_-143-_jpg.rf.0929da80a3e0ef186de5e9816798c5e5.jpg: 416x416 1 Heavy Vehicle, Done. (0.032s)
# image 51/117 /content/yolov5/Roadside-Object-Detection-7/test/images/hv_-22-_jpg.rf.a4c4aff657f17543ec49140167709edf.jpg: 416x416 Done. (0.031s)
# image 52/117 /content/yolov5/Roadside-Object-Detection-7/test/images/hv_-69-_jpg.rf.756de6aa1f2e5b1e2487a646df472ba6.jpg: 416x416 1 Car, Done. (0.032s)
# image 53/117 /content/yolov5/Roadside-Object-Detection-7/test/images/hv_-82-_jpg.rf.b67104f8b8817f4990acd19f6acfa22e.jpg: 416x416 2 Heavy Vehicles, Done. (0.032s)
# image 54/117 /content/yolov5/Roadside-Object-Detection-7/test/images/hv_-88-_jpg.rf.5da21c5bb06a70f873a46d81f2de6014.jpg: 416x416 1 Heavy Vehicle, Done. (0.033s)
# image 55/117 /content/yolov5/Roadside-Object-Detection-7/test/images/hv_-93-_jpg.rf.1b4fc47191ea1881495b02baf9b65691.jpg: 416x416 1 Car, Done. (0.031s)
# image 56/117 /content/yolov5/Roadside-Object-Detection-7/test/images/index1_jpg.rf.159655f52ee530ddd3b5129d5f89f40f.jpg: 416x416 Done. (0.031s)
# image 57/117 /content/yolov5/Roadside-Object-Detection-7/test/images/index6_jpg.rf.77c86dfd55f88e16042a61c5c6ac6231.jpg: 416x416 Done. (0.031s)
# image 58/117 /content/yolov5/Roadside-Object-Detection-7/test/images/n008-2018-08-01-15-16-36-0400__CAM_BACK_LEFT__1533151606547405_jpg.rf.f3a6f920a89a0d49994499d36634006b.jpg: 416x416 Done. (0.031s)
# image 59/117 /content/yolov5/Roadside-Object-Detection-7/test/images/n008-2018-08-01-15-16-36-0400__CAM_BACK_LEFT__1533151611447405_jpg.rf.aea55b41deb67112ffb2d31299b40833.jpg: 416x416 1 Car, Done. (0.032s)
# image 60/117 /content/yolov5/Roadside-Object-Detection-7/test/images/n008-2018-08-01-15-16-36-0400__CAM_BACK_LEFT__1533151622447405_jpg.rf.a7d678fd6f5c72cf25ebcc1c8578bbc2.jpg: 416x416 1 Heavy Vehicle, Done. (0.032s)
# image 108/117 /content/yolov5/Roadside-Object-Detection-7/test/images/n015-2018-10-08-15-36-50-0800__CAM_FRONT__1538984239912460_jpg.rf.09ded4b5f9329b4e4c28c7742a05bcae.jpg: 416x416 3 Cars, Done. (0.032s)
# image 109/117 /content/yolov5/Roadside-Object-Detection-7/test/images/n015-2018-10-08-15-36-50-0800__CAM_FRONT__1538984246412460_jpg.rf.210bfe2ab25e5e67fcd30b2eb25124a3.jpg: 416x416 3 Cars, 1 Heavy Vehicle, Done. (0.032s)
# image 110/117 /content/yolov5/Roadside-Object-Detection-7/test/images/n015-2018-11-21-19-38-26-0800__CAM_BACK_RIGHT__1542800851927893_jpg.rf.79c224965e910d086b0fad112009bab2.jpg: 416x416 Done. (0.031s)
# image 111/117 /content/yolov5/Roadside-Object-Detection-7/test/images/n015-2018-11-21-19-38-26-0800__CAM_BACK_RIGHT__1542800993377893_jpg.rf.f8d93b1377db4f69c1249ab289aa5168.jpg: 416x416 1 Car, Done. (0.032s)
# image 112/117 /content/yolov5/Roadside-Object-Detection-7/test/images/n015-2018-11-21-19-38-26-0800__CAM_BACK_RIGHT__1542801003427893_jpg.rf.918a91b43685602df08a166f35469756.jpg: 416x416 Done. (0.032s)
# image 113/117 /content/yolov5/Roadside-Object-Detection-7/test/images/n015-2018-11-21-19-38-26-0800__CAM_FRONT_RIGHT__1542800369920339_jpg.rf.29d9798cab5650128cf53341bc3bcc62.jpg: 416x416 2 Cars, Done. (0.033s)
# image 114/117 /content/yolov5/Roadside-Object-Detection-7/test/images/n015-2018-11-21-19-38-26-0800__CAM_FRONT_RIGHT__1542800849420339_jpg.rf.1229271bfbe643f30b921556127fa29c.jpg: 416x416 1 Car, Done. (0.032s)
# image 115/117 /content/yolov5/Roadside-Object-Detection-7/test/images/n015-2018-11-21-19-38-26-0800__CAM_FRONT_RIGHT__1542800867420339_jpg.rf.d793502b8ef2ad116640d5fa6a745eb4.jpg: 416x416 Done. (0.031s)
# image 116/117 /content/yolov5/Roadside-Object-Detection-7/test/images/n015-2018-11-21-19-38-26-0800__CAM_FRONT__1542800863412460_jpg.rf.cecf87c20a8168477b6588b4cc4a376c.jpg: 416x416 2 Cars, Done. (0.032s)
# image 117/117 /content/yolov5/Roadside-Object-Detection-7/test/images/n015-2018-11-21-19-38-26-0800__CAM_FRONT__1542800863912460_jpg.rf.bbd2ffdcfc18c3ec43411bc31b298cac.jpg: 416x416 2 Cars, Done. (0.033s)
# Results saved to runs/detect/exp2
# Done. (7.482s)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#display inference on ALL test images
#this looks much better with longer training above

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# # Export Trained Weights for Future Inference
#
# Now that you have trained your custom detector, you can export the trained weights you have made here for inference on your device elsewhere

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cp /content/yolov5/runs/train/yolov5s_results/weights/best.pt /content/gdrive/My\ Drive

# %% [markdown]
# ## Congrats!
#
# Hope you enjoyed this!
#
# --Team [Roboflow](https://roboflow.ai)
